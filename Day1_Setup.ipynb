# %% [markdown]
# <a href="https://colab.research.google.com/github/seetach/AI-mentor-portfolio---Ch-seeta-mahalakshmi/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the hierarchical skills needed to build and deploy effective AI solutions:
#
# *   **Foundation:** It starts with foundational **Data & Infrastructure**, providing the raw materials and computational power (e.g., data engineering, cloud platforms).
# *   **Core AI:** The next layers involve **Machine Learning Models & Algorithms** and the **Tools & Frameworks** (e.g., Python, TensorFlow, MLOps) used to build and deploy them.
# *   **Applications:** These culminate in functional **Applications & Solutions**, where AI is integrated into products and services to solve specific problems.
# *   **Apex:** The pyramid's apex is **Domain Expertise & Business Acumen**, crucial for ensuring AI solutions are relevant, ethical, and deliver real-world strategic value.

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='recursion the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# Here's recursion applied to the 5-Layer AI Skill Pyramid in 4 short bullet points:
#
# *   **Foundation (Data & Algorithms):** Recursion is crucial for parsing nested data structures (e.g., JSON, XML) and underpins many fundamental algorithms like tree traversals and divide-and-conquer strategies.
# *   **Model Building:** It informs the design of hierarchical model architectures (e.g., recursive neural networks for sequences) and conceptualizes iterative refinement processes in training.
# *   **System Deployment:** Recursion enables building robust, interactive AI systems with feedback loops, nested process orchestration, and complex decision-making paths.
# *   **Meta-Learning & Innovation:** At the apex, recursion is key for developing self-improving AI, meta-learning algorithms (learning to learn), and designing truly adaptive, recursively defined intelligent agents.
