# %% [markdown]
# <a href="https://colab.research.google.com/github/seetach/AI-mentor-portfolio---Ch-seeta-mahalakshmi/blob/main/Day6_PlacementProcessor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai pydantic

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Gemini API key: ")
# Out:
# Gemini API key: ··········

# %%
from pydantic import BaseModel
from typing import List, Optional

class Education(BaseModel):
    degree: str
    institution: str
    year: int

class Resume(BaseModel):
    name: str
    email: str
    phone: Optional[str] = None
    education: List[Education]
    skills: List[str]
    projects: List[str] = []
    experience_years: float

# %%
from google import genai
from pydantic import ValidationError

client = genai.Client(
    api_key=os.environ["GEMINI_API_KEY"]
)

def extract_resume(raw_text: str,
                   max_retries: int = 1):

    for attempt in range(max_retries + 1):

        try:

            resp = client.models.generate_content(
                model="gemini-2.5-flash",

                contents=f"""
                Extract Resume JSON.

                Return ONLY JSON.

                Resume text:
                {raw_text}
                """,

                config={
                    "response_mime_type":
                    "application/json",

                    "response_schema":
                    Resume.model_json_schema(),
                },
            )

            return Resume.model_validate_json(
                resp.text
            )

        except ValidationError as e:

            if attempt == max_retries:
                raise

            fix_prompt = f"""
            Fix JSON schema errors.

            Errors:
            {e}

            Original:
            {resp.text}
            """

            resp = client.models.generate_content(
                model="gemini-2.5-flash",

                contents=fix_prompt,

                config={
                    "response_mime_type":
                    "application/json",

                    "response_schema":
                    Resume.model_json_schema(),
                },
            )

            return Resume.model_validate_json(
                resp.text
            )

# %%
sample_resume = """
Seeta Mahalakshmi

Email: seeta@gmail.com
Phone: 9876543210

Education:
B.Tech in Computer Science
ABC Engineering College
2026

Skills:
Python, SQL, AWS, Docker, Git

Projects:
Cloud Monitoring System
Resume Scorer App

Experience:
1.5 years internship experience
"""

# %%
parsed = extract_resume(sample_resume)

print(parsed)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_540/2112766911.py in <cell line: 0>()
# ----> 1 parsed = extract_resume(sample_resume)
#       2
#       3 print(parsed)
#
# /tmp/ipykernel_540/2367583830.py in extract_resume(raw_text, max_retries)
#      13         try:
#      14
# ---> 15             resp = client.models.generate_content(
#      16                 model="gemini-2.5-flash",
#      17
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5862     while remaining_remote_calls_afc > 0:
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#    5866       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
# ...

# %%
import os

os.environ["GEMINI_API_KEY"] = "AIzaSyBcjfjlbjjr1tuTkuoI53Y-Ylsp6oRpyoc"

# %%
from google import genai

client = genai.Client(
    api_key=os.environ["GEMINI_API_KEY"]
)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="hello"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_540/36017852.py in <cell line: 0>()
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-2.5-flash",
#       3     contents="hello"
#       4 )
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5862     while remaining_remote_calls_afc > 0:
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#    5866       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4524     request_dict = _common.encode_unserializable_types(request_dict)
#    4525
# -> 4526     response = self._api_client.request(
# ...

# %%
# !pip install -q google-genai pydantic

# %%
import os

os.environ["GEMINI_API_KEY"] = "AIzaSyAmQzTDfqhk1Ih41cl7llYytzkxpn98VZw"

# %%
from google import genai

client = genai.Client(
    api_key=os.environ["GEMINI_API_KEY"]
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="hello"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_540/1842211182.py in <cell line: 0>()
#       5 )
#       6
# ----> 7 response = client.models.generate_content(
#       8     model="gemini-2.5-flash",
#       9     contents="hello"
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5862     while remaining_remote_calls_afc > 0:
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#    5866       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4524     request_dict = _common.encode_unserializable_types(request_dict)
#    4525
# -> 4526     response = self._api_client.request(
# ...

# %%
mock_resume = Resume(
    name="Seeta Mahalakshmi",
    email="seeta@gmail.com",
    phone="9876543210",

    education=[
        Education(
            degree="B.Tech CSE",
            institution="ABC Engineering College",
            year=2026
        )
    ],

    skills=[
        "Python",
        "SQL",
        "AWS",
        "Docker"
    ],

    projects=[
        "Resume Scorer",
        "Career Agent"
    ],

    experience_years=1.5
)

print(mock_resume)
# Out:
# name='Seeta Mahalakshmi' email='seeta@gmail.com' phone='9876543210' education=[Education(degree='B.Tech CSE', institution='ABC Engineering College', year=2026)] skills=['Python', 'SQL', 'AWS', 'Docker'] projects=['Resume Scorer', 'Career Agent'] experience_years=1.5

# %%
print(
    mock_resume.model_dump_json(indent=2)
)
# Out:
# {
#   "name": "Seeta Mahalakshmi",
#   "email": "seeta@gmail.com",
#   "phone": "9876543210",
#   "education": [
#     {
#       "degree": "B.Tech CSE",
#       "institution": "ABC Engineering College",
#       "year": 2026
#     }
#   ],
#   "skills": [
#     "Python",
#     "SQL",
#     "AWS",
#     "Docker"
#   ],
#   "projects": [
#     "Resume Scorer",
#     "Career Agent"
#   ],
#   "experience_years": 1.5
# }

# %%
try:
    bad = Resume(
        name="Test",
        email="badmail",
        education=[],
        skills=[],
        experience_years="abc"
    )

except Exception as e:
    print(type(e).__name__)
    print(e)
# Out:
# ValidationError
# 1 validation error for Resume
# experience_years
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='abc', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/float_parsing

# %%
from typing import List, Optional
from pydantic import BaseModel

class JD(BaseModel):
    company: str
    role: str
    must_have_skills: List[str]
    nice_to_have_skills: List[str] = []
    min_cgpa: Optional[float] = None
    locations: List[str] = []
    package_lpa: Optional[float] = None

# %%
# !pip install -q beautifulsoup4 requests

# %%
import requests
from bs4 import BeautifulSoup

def fetch_jd(url, max_chars=3000):

    try:

        r = requests.get(
            url,
            headers={"User-Agent": "Mozilla/5.0"},
            timeout=10
        )

        r.raise_for_status()

        soup = BeautifulSoup(
            r.text,
            "html.parser"
        )

        for tag in soup(["script", "style"]):
            tag.decompose()

        text = soup.get_text(
            separator="\n",
            strip=True
        )

        return text[:max_chars]

    except Exception as e:

        print("Scrape failed:", e)
        return None

# %%
test_url = "https://jobs.careers.microsoft.com/global/en/job/1801920"

text = fetch_jd(test_url)

if text:
    print(text[:1000])
else:
    print("Scraping failed")
# Out:
# 654c6aaa25ad4751986d2b4fdcf3da6f-b7d405fc-078f-42fd-99cf-e21de3479349-7421
# Careers at Microsoft
# ...

# %%
mock_jd = JD(
    company="Microsoft",

    role="Software Engineer Intern",

    must_have_skills=[
        "Python",
        "Data Structures",
        "Algorithms",
        "Git"
    ],

    nice_to_have_skills=[
        "Azure",
        "Docker"
    ],

    min_cgpa=7.5,

    locations=[
        "Hyderabad",
        "Bangalore"
    ],

    package_lpa=18.0
)

print(
    mock_jd.model_dump_json(indent=2)
)
# Out:
# {
#   "company": "Microsoft",
#   "role": "Software Engineer Intern",
#   "must_have_skills": [
#     "Python",
#     "Data Structures",
#     "Algorithms",
#     "Git"
#   ],
#   "nice_to_have_skills": [
#     "Azure",
#     "Docker"
#   ],
#   "min_cgpa": 7.5,
#   "locations": [
#     "Hyderabad",
#     "Bangalore"
#   ],
#   "package_lpa": 18.0
# }

# %%
jds = [

    JD(
        company="TCS",
        role="Digital Engineer",
        must_have_skills=["Java", "SQL"],
        package_lpa=7.0
    ),

    JD(
        company="Infosys",
        role="Systems Engineer",
        must_have_skills=["Python", "AWS"],
        package_lpa=6.5
    ),

    mock_jd
]

print(f"Created {len(jds)} JDs")
# Out:
# Created 3 JDs

# %%
import json
import pathlib

OUT = pathlib.Path("data/jds.jsonl")

OUT.parent.mkdir(exist_ok=True)

with open(OUT, "w") as f:

    for jd in jds:

        f.write(
            jd.model_dump_json()
            + "\n"
        )

print(f"Wrote {len(jds)} JDs to {OUT}")
# Out:
# Wrote 3 JDs to data/jds.jsonl

# %%
with open("data/jds.jsonl") as f:

    for line in f:

        d = json.loads(line)

        print(
            f"{d['company']} | "
            f"{d['role']} | "
            f"{len(d['must_have_skills'])} skills"
        )
# Out:
# TCS | Digital Engineer | 2 skills
# Infosys | Systems Engineer | 2 skills
# Microsoft | Software Engineer Intern | 4 skills
