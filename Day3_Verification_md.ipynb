# %% [markdown]
# <a href="https://colab.research.google.com/github/seetach/AI-mentor-portfolio---Ch-seeta-mahalakshmi/blob/main/Day3_Verification_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Verification Chain
#
#   "List 5 specific statistics about Indian campus placement in 2025-2026. For each: state the number, the year, and the source organisation. Format as a numbered list."
#
# Example:
#
# > 1. The average B.Tech placement package in Indian engineering colleges in 2025 was ₹6.2 LPA.
# > 2. 78% of Tier-1 college students received at least one placement offer in 2025.
# > 3. TCS hired approximately 40,000 freshers in 2025.
# > 4. The IT services sector accounted for 56% of all engineering placements in India in 2025.
# > 5. The median placement package at IITs in 2025 was ₹18.5 LPA.

# %% [markdown]
# ![Screenshot 2026-05-21 145030.png](data:image/png;base64,...)
