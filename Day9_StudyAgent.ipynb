# %% [markdown]
# <a href="https://colab.research.google.com/github/seetach/AI-mentor-portfolio---Ch-seeta-mahalakshmi/blob/main/Day9_StudyAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langgraph langchain-google-genai langchain-community duckduckgo-search
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 79.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
import os, getpass

os.environ['GEMINI_API_KEY'] = getpass.getpass('Gemini API key: ')
# Out:
# Gemini API key: ··········

# %%
from langchain_core.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun

@tool
def web_search(query: str) -> str:
    """Search the web for latest information."""
    return DuckDuckGoSearchRun().run(query)

print(web_search.invoke({'query': 'TCS hiring 2026'})[:400])
# Out:
# /tmp/ipykernel_4124/2946708835.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_community/utilities/duckduckgo_search.py in validate_environment(cls, values)
#      48         try:
# ---> 49             from ddgs import DDGS  # noqa: F401
#      50         except ImportError:
#
# ModuleNotFoundError: No module named 'ddgs'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_4124/2946708835.py in <cell line: 0>()
# ...

# %%
# !pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 8.3 MB/s eta 0:00:00
# ...

# %%
from langchain_core.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun

@tool
def web_search(query: str) -> str:
    """Search the web for latest information."""
    return DuckDuckGoSearchRun().run(query)

print(web_search.invoke({'query': 'TCS hiring 2026'})[:400])
# Out:
# Aug 8, 2025 · TCS BPS Hiring - Batch of 2026. TCS BPS is bringing inspiring entry-level opportunities for Arts and Commerce graduates. As part of Business Processing ... Feb 17, 2026 · TCS NQT Hiring Announced 2026,2025,2024. 11K views · 3 months ago ...more. Ashish Kumar. 123K. Subscribe. 363. Share. Save. Report. Comments. Mar 11, 2026 · Tata Consultancy Services (TCS) has officially announced t

# %%
import os, getpass

os.environ['GEMINI_API_KEY'] = getpass.getpass('Gemini API key: ')
# Out:
# Gemini API key: ··········

# %%
from langgraph.prebuilt import create_react_agent
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

agent = create_react_agent(
    llm,
    tools=[web_search]
)

print("Agent created")
# Out:
# Agent created
# /tmp/ipykernel_4124/3267650005.py:6: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(

# %%
result = agent.invoke({
    'messages': [('user', "What is TCS's 2026 hiring quota?")]
})

for i, m in enumerate(result['messages']):
    print(f'\n[{i}] {type(m).__name__}')

    if hasattr(m, 'content'):
        print(f'Content: {str(m.content)[:300]}')

    if hasattr(m, 'tool_calls') and m.tool_calls:
        print(f'Tool calls: {m.tool_calls}')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165         try:
# -> 3166             response: GenerateContentResponse = self.client.models.generate_content(
#    3167                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5848         )
# -> 5849       return self._generate_content(
#    5850           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4525
# -> 4526     response = self._api_client.request(
# ...

# %%
import os

if "GEMINI_API_KEY" in os.environ:
    del os.environ["GEMINI_API_KEY"]

print("Old key removed")
# Out:
# Old key removed

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Paste NEW Gemini API key: ")
# Out:
# Paste NEW Gemini API key: ··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.environ["GEMINI_API_KEY"]
)

print(llm.invoke("hello").content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165         try:
# -> 3166             response: GenerateContentResponse = self.client.models.generate_content(
#    3167                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4525
# -> 4526     response = self._api_client.request(
# ...

# %%
import os

os.environ["GEMINI_API_KEY"] = "AIzaSyA0vLLlE3t7BsJoZpzjDj4mUdwZoJRNCiw"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.environ["GEMINI_API_KEY"]
)

print(llm.invoke("hello").content)
# Out:
# Hello! How can I help you today?

# %%
from langgraph.prebuilt import create_react_agent
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.environ["GEMINI_API_KEY"]
)

agent = create_react_agent(
    llm,
    tools=[web_search]
)

print("Agent created successfully")
# Out:
# Agent created successfully
# /tmp/ipykernel_4124/2346299487.py:9: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(

# %%
result = agent.invoke({
    'messages': [('user', "What is TCS's 2026 hiring quota?")]
})

for i, m in enumerate(result['messages']):
    print(f'\n[{i}] {type(m).__name__}')

    if hasattr(m, 'content'):
        print(f'Content: {str(m.content)[:300]}')

    if hasattr(m, 'tool_calls') and m.tool_calls:
        print(f'Tool calls: {m.tool_calls}')
# Out:
# [0] HumanMessage
# Content: What is TCS's 2026 hiring quota?
#
# [1] AIMessage
# Content:
# Tool calls: [{'name': 'web_search', 'args': {'query': 'TCS 2026 hiring quota'}, 'id': '1f9f410c-521d-4fbd-aecf-e6c2168e8d6b', 'type': 'tool_call'}]
#
# [2] ToolMessage
# Content: Apr 8, 2026 · Tata Consultancy Services (TCS) (BSE: 532540, NSE: TCS) is a digital transformation and technology partner of choice for industry-leading organizations worldwide. Discover the latest TCS hiring 2026 updates, including TCS recruitment 2026, upcoming TCS jobs 2026, and all new TCS vacanc
#
# [3] AIMessage
# Content: [{'type': 'text', 'text': "TCS has made 25,000 job offers to fresh graduates for FY2026-27. The company aims to onboard around 40,000 freshers annually. It's also worth noting that TCS reported a headcount reduction of 23,460 in FY26.", 'extras': {'signature': 'CvYCAQw51sd+edsE3cQsAo+WbwNqr5nxzj/MFN

# %%
result = agent.invoke({
    'messages': [('user',
    'Search this URL and tell me what it says: https://this-domain-does-not-exist-12345.example.com/jd')]
})

for i, m in enumerate(result['messages']):
    print(f'\n[{i}] {type(m).__name__}')

    if hasattr(m, 'content'):
        print(str(m.content)[:300])
# Out:
# [0] HumanMessage
# Search this URL and tell me what it says: https://this-domain-does-not-exist-12345.example.com/jd
#
# [1] AIMessage
# [{'type': 'text', 'text': "I cannot directly search the content of a specific URL like that. My `web_search` tool is designed to search the web using a query, not to fetch and interpret the content of a given URL.\n\nAdditionally, the URL you provided, `https://this-domain-does-not-exist-12345.examp
